# %% [markdown]
# # 📊 Portfolio Optimization and Risk Analysis Tool
#
# This interactive cell builds a complete **Mean–Variance Portfolio Optimization** environment using `yfinance`, `numpy`, `pandas`, `scipy`, and `ipywidgets`.
# It allows the user to download historical price data, compute annualized returns and covariances, and visualize optimal portfolios and risk metrics.
#
# **Main features:**
#
# 1. **Widget Interface** – Interactive sliders and input fields let the user define:
#    - The number of historical months to use,
#    - Total capital (€),
#    - Confidence level for Value at Risk (VaR),
#    - Minimum acceptable return \( m_0 \),
#    - and the list of stock tickers.
#
# 2. **Automatic Data Retrieval** – Downloads adjusted closing prices from **Yahoo Finance** for all selected tickers and computes daily percentage returns.
#
# 3. **Portfolio Optimization** – Uses numerical optimization (`scipy.optimize.minimize`) to construct:
#    - Minimum Variance Portfolio,
#    - Maximum Sharpe Ratio Portfolio,
#    - Minimum Variance Portfolio with return ≥ \( m_0 \),
#    - and the **Efficient Frontier** curve.
#
# 4. **Risk Analysis** – Calculates **daily Value at Risk (VaR)** for each optimized portfolio, based on the selected confidence level and capital amount.
#
# 5. **Visualization & Output** –
#    - Plots the Efficient Frontier and marks each key portfolio point.
#    - Displays portfolio weights, returns, volatilities, and VaR values.
#    - Generates LaTeX tables for annualized returns and covariance matrices, ready to include in reports or papers.
#
# This cell combines quantitative finance, optimization, and risk management tools into a single interactive environment that is fully compatible with **Google Colab**.

# %%
# ----------------------
# Απαιτούμενα πακέτα
# (Σε Colab: !pip install yfinance ipywidgets matplotlib numpy pandas scipy)
# ----------------------
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from scipy.optimize import minimize
from scipy.stats import norm
import ipywidgets as widgets
from IPython.display import display

# ----------------------------------------
# Συνάρτηση Εξαγωγής σε LaTeX
# ----------------------------------------
def export_to_latex(annual_returns, annual_cov_matrix, tickers):
    """
    Εξάγει τους πίνακες των ετήσιων αποδόσεων και της συνδιακύμανσης σε LaTeX format.
    Επιστρέφει δύο συμβολοσειρές: LaTeX πίνακας αποδόσεων και συνδιακύμανσης.
    """
    # --- Πίνακας Ετήσιων Αποδόσεων ---
    returns_df = pd.DataFrame({
        "Ticker": tickers,
        "Annual Return": [annual_returns[t] for t in tickers]
    }).set_index("Ticker")

    latex_returns = returns_df.to_latex(
        float_format="%.6f",
        caption="Ετήσιες Αποδόσεις Μετοχών",
        label="tab:annual_returns",
        escape=False
    )

    # --- Πίνακας Συνδιακύμανσης ---
    cov_df = pd.DataFrame(annual_cov_matrix, index=tickers, columns=tickers)
    latex_cov = cov_df.to_latex(
        float_format="%.6f",
        caption="Πίνακας Ετήσιας Συνδιακύμανσης",
        label="tab:annual_covariance",
        escape=False
    )

    return latex_returns, latex_cov


# ----------------------
# Widgets για είσοδο
# ----------------------
# Αντικατάσταση του months_slider με επιλογή start/end date
start_date_picker = widgets.DatePicker(
    description='Ημερομηνία Έναρξης:',
    value=(datetime.today() - timedelta(days=365)).date()  # προεπιλογή ~12 μήνες πίσω
)

end_date_picker = widgets.DatePicker(
    description='Ημερομηνία Λήξης:',
    value=(datetime.today() - timedelta(days=1)).date()    # προεπιλογή: χθες
)

capital_input = widgets.FloatText(
    value=100000,
    description='Κεφάλαιο (€):',
    disabled=False
)

confidence_slider = widgets.FloatSlider(
    value=0.95,
    min=0.8,
    max=0.99,
    step=0.01,
    description='Επίπεδο εμπιστοσύνης:',
    readout_format='.2f'
)

m0_input = widgets.FloatText(
    value=0.05,
    description='Ελάχιστη Απόδοση (m₀):',
    disabled=False
)

stock_input = widgets.Text(
    value='AAPL,MSFT,GOOG,TSLA',
    placeholder='Εισάγετε μετοχές (π.χ. AAPL,MSFT,TSLA)',
    description='Μετοχές:',
    disabled=False
)

button = widgets.Button(description="Υπολογισμός")
output = widgets.Output()


# ----------------------
# Συνάρτηση υπολογισμού
# ----------------------
def calculate(button):
    global data, valid_tickers, annual_returns, annual_cov_matrix
    global min_var_m0_weights, min_m0_ret, min_m0_vol
    global capital_input, m0_input
    output.clear_output()

    ticker_input = stock_input.value.strip()
    capital = capital_input.value
    confidence_level = confidence_slider.value
    m0 = m0_input.value

    # Μετατροπή από DatePicker (date) σε datetime
    sd = start_date_picker.value
    ed = end_date_picker.value

    if sd is None or ed is None:
        with output:
            print("❗Παρακαλώ επιλέξτε έγκυρες ημερομηνίες έναρξης και λήξης.")
        return

    start_date = datetime.combine(sd, datetime.min.time())
    end_date = datetime.combine(ed, datetime.min.time())

    if start_date >= end_date:
        with output:
            print("❗Η ημερομηνία έναρξης πρέπει να είναι προγενέστερη της ημερομηνίας λήξης.")
        return

    if not ticker_input:
        with output:
            print("❗Παρακαλώ εισάγετε τουλάχιστον μία μετοχή.")
        return

    tickers_input_order = [t.strip().upper() for t in ticker_input.split(',')]

    with output:
        print(f"Λήψη δεδομένων από {start_date.strftime('%Y-%m-%d')} μέχρι {end_date.strftime('%Y-%m-%d')}")
        print("Tickers (input order):", tickers_input_order)

        try:
            data = yf.download(tickers_input_order, start=start_date, end=end_date)['Close']

            if data.empty:
                print("❗Δεν βρέθηκαν δεδομένα.")
                return

            valid_tickers = [col for col in tickers_input_order if col in data.columns]
            if not valid_tickers:
                print("❗Δεν βρέθηκαν δεδομένα για κανένα ticker.")
                return

            data = data[valid_tickers]
            # --- Γράφημα Τιμών για το Επιλεγμένο Διάστημα ---
            plt.figure(figsize=(10, 5))
            data.plot(ax=plt.gca())  # ένα γράφημα με όλες τις μετοχές
            plt.title(f"Τιμές Κλεισίματος ({start_date.strftime('%Y-%m-%d')} → {end_date.strftime('%Y-%m-%d')})")
            plt.xlabel("Ημερομηνία")
            plt.ylabel("Τιμή Κλεισίματος")
            plt.legend(title="Ticker")
            plt.grid(True)
            plt.show()

            returns = data.pct_change().dropna()

            annual_returns = returns.mean() * 252
            annual_cov_matrix = returns.cov() * 252
            num_assets = len(valid_tickers)

            # --- Εκτύπωση Ετήσιων Αποδόσεων και Συνδιακύμανσης ---
            print("\n📈 Ετήσιες Αποδόσεις Μετοχών:")
            for ticker in valid_tickers:
                print(f"{ticker}: {annual_returns[ticker]:.4f} ({annual_returns[ticker]*100:.2f}%)")

            print("\n📊 Πίνακας Ετήσιας Συνδιακύμανσης:")
            cov_df = pd.DataFrame(annual_cov_matrix, index=valid_tickers, columns=valid_tickers)
            display(cov_df.style.format("{:.6f}").set_caption("Annual Covariance Matrix"))

            # ---------------------------------------
            # Βοηθητικές συναρτήσεις
            # ---------------------------------------
            def portfolio_stats(weights, mean_returns, cov_matrix):
                portfolio_return = np.sum(mean_returns * weights)
                portfolio_volatility = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))
                return portfolio_return, portfolio_volatility

            def minimize_volatility(weights, mean_returns, cov_matrix):
                return portfolio_stats(weights, mean_returns, cov_matrix)[1]

            def neg_sharpe_ratio(weights, mean_returns, cov_matrix, risk_free_rate=0):
                ret, vol = portfolio_stats(weights, mean_returns, cov_matrix)
                sharpe = (ret - risk_free_rate) / vol
                return -sharpe

            constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
            bounds = tuple((0, 1) for _ in range(num_assets))
            initial_guess = [1. / num_assets] * num_assets

            # 1️⃣ Minimum Variance Portfolio
            res_min_var = minimize(minimize_volatility, initial_guess,
                                   args=(annual_returns, annual_cov_matrix),
                                   method='SLSQP', bounds=bounds, constraints=constraints)
            min_var_weights = res_min_var.x
            min_ret, min_vol = portfolio_stats(min_var_weights, annual_returns, annual_cov_matrix)

            # 2️⃣ Optimal (Maximum Sharpe Ratio) Portfolio
            res_opt = minimize(neg_sharpe_ratio, initial_guess,
                               args=(annual_returns, annual_cov_matrix, 0),
                               method='SLSQP', bounds=bounds, constraints=constraints)
            opt_weights = res_opt.x
            opt_ret, opt_vol = portfolio_stats(opt_weights, annual_returns, annual_cov_matrix)

            # 3️⃣ Min Variance Portfolio με Απόδοση ≥ m₀
            constraints_m0 = (
                {'type': 'eq', 'fun': lambda x: np.sum(x) - 1},
                {'type': 'ineq', 'fun': lambda x: np.sum(x * annual_returns) - m0}
            )
            res_min_var_m0 = minimize(minimize_volatility, initial_guess,
                                      args=(annual_returns, annual_cov_matrix),
                                      method='SLSQP', bounds=bounds, constraints=constraints_m0)
            min_var_m0_weights = res_min_var_m0.x
            min_m0_ret, min_m0_vol = portfolio_stats(min_var_m0_weights, annual_returns, annual_cov_matrix)

            # 4️⃣ Efficient Frontier
            target_returns = np.linspace(min(annual_returns), max(annual_returns), 50)
            frontier_vols = []

            for r in target_returns:
                constraints_frontier = (
                    {'type': 'eq', 'fun': lambda x: np.sum(x) - 1},
                    {'type': 'eq', 'fun': lambda x: np.sum(x * annual_returns) - r}
                )
                res = minimize(minimize_volatility, initial_guess,
                               args=(annual_returns, annual_cov_matrix),
                               method='SLSQP', bounds=bounds, constraints=constraints_frontier)
                if res.success:
                    frontier_vols.append(portfolio_stats(res.x, annual_returns, annual_cov_matrix)[1])
                else:
                    frontier_vols.append(np.nan)

            # 5️⃣ Value at Risk (VaR)
            z_score = norm.ppf(1 - confidence_level)
            var_opt_daily = -(opt_ret / 252 + z_score * (opt_vol / np.sqrt(252)))
            var_min_daily = -(min_ret / 252 + z_score * (min_vol / np.sqrt(252)))
            var_min_m0_daily = -(min_m0_ret / 252 + z_score * (min_m0_vol / np.sqrt(252)))

            var_opt_eur = capital * var_opt_daily
            var_min_eur = capital * var_min_daily
            var_min_m0_eur = capital * var_min_m0_daily

            # 6️⃣ Διάγραμμα Efficient Frontier
            plt.figure(figsize=(10, 6))
            plt.plot(frontier_vols, target_returns, color='gray', lw=2, label='Efficient Frontier')
            plt.scatter(min_vol, min_ret, color='blue', marker='o', s=100, label='Min Variance')
            plt.scatter(opt_vol, opt_ret, color='red', marker='*', s=200, label='Optimal (Sharpe)')
            plt.scatter(min_m0_vol, min_m0_ret, color='green', marker='s', s=120,
                        label=f'Min Var (≥ {m0:.2%})')
            plt.xlabel('Annual Risk (Volatility)')
            plt.ylabel('Annual Return')
            plt.title('Efficient Frontier with Constraints')
            plt.legend()
            plt.grid(True)
            plt.show()

            # 7️⃣ Εκτύπωση Αποτελεσμάτων
            print("\n\n📌 Βέλτιστο Πορτοφόλιο (Sharpe Ratio):")
            for ticker, weight in zip(valid_tickers, opt_weights):
                print(f"{ticker}: {weight:.4f} ({weight*100:.2f}%)")
            print(f"\nΑπόδοση: {opt_ret:.4f} ({opt_ret*100:.2f}%)  |  Volatility: {opt_vol:.4f} ({opt_vol*100:.2f}%)")
            print(f"Ημερήσιο VaR σε €: €{-var_opt_eur:.2f}")

            print("\n📘 Χαρτοφυλάκιο Ελάχιστης Διακύμανσης:")
            for ticker, weight in zip(valid_tickers, min_var_weights):
                print(f"{ticker}: {weight:.4f} ({weight*100:.2f}%)")
            print(f"\nΑπόδοση: {min_ret:.4f} ({min_ret*100:.2f}%)  |  Volatility: {min_vol:.4f} ({min_vol*100:.2f}%)")
            print(f"Ημερήσιο VaR σε €: €{-var_min_eur:.2f}")

            print("\n📗 Χαρτοφυλάκιο Ελάχιστης Διακύμανσης με Απόδοση ≥ m₀:")
            for ticker, weight in zip(valid_tickers, min_var_m0_weights):
                print(f"{ticker}: {weight:.4f} ({weight*100:.2f}%)")
            print(f"\nΑπόδοση: {min_m0_ret:.4f} ({min_m0_ret*100:.2f}%)  |  Volatility: {min_m0_vol:.4f} ({min_m0_vol*100:.2f}%)")
            print(f"Ημερήσιο VaR σε €: €{-var_min_m0_eur:.2f}")

            # 8️⃣ Εξαγωγή σε LaTeX
            latex_returns, latex_cov = export_to_latex(annual_returns, annual_cov_matrix, valid_tickers)
            print("\n📄 --- LaTeX Πίνακας Αποδόσεων ---")
            print(latex_returns)
            print("\n📄 --- LaTeX Πίνακας Συνδιακύμανσης ---")
            print(latex_cov)

        except Exception as e:
            print("Σφάλμα:", str(e))


# ----------------------
# Σύνδεση κουμπιού
# ----------------------
button.on_click(calculate)

# ----------------------
# Εμφάνιση interface
# ----------------------
display(
    start_date_picker,
    end_date_picker,
    capital_input,
    confidence_slider,
    m0_input,
    stock_input,
    button,
    output
)
# Out:
# DatePicker(value=datetime.date(2024, 11, 7), description='Ημερομηνία Έναρξης:')
# DatePicker(value=datetime.date(2025, 11, 6), description='Ημερομηνία Λήξης:')
# FloatText(value=100000.0, description='Κεφάλαιο (€):')
# FloatSlider(value=0.95, description='Επίπεδο εμπιστοσύνης:', max=0.99, min=0.8, step=0.01)
# FloatText(value=0.05, description='Ελάχιστη Απόδοση (m₀):')
# Text(value='AAPL,MSFT,GOOG,TSLA', description='Μετοχές:', placeholder='Εισάγετε μετοχές (π.χ. AAPL,MSFT,TSLA)'…
# Button(description='Υπολογισμός', style=ButtonStyle())
# Output()

# %% [markdown]
# ### 📘 Description: Portfolio Profit Function
#
# The following cell visualizes the **profit function** of the **minimum-variance portfolio**
# with target return
# $\geq m_0$ in the case where the portfolio consists of **two assets**.
#
# The profit function is defined as:
#
# $$
# \Pi(x, y) = a x + b y - V
# $$
#
# where:
#
# - \(x, y\) are the prices of the two assets,
# - \(a, b\) are the numbers of shares of each asset in the portfolio,
# - \(V\) is the total invested capital.
#
# The 3D plot illustrates the profit (or loss) of the investor for all possible price combinations
# $$x, y \ge 0$$ up to **twice the current price** of each asset.
#
# The surface shows how the portfolio’s profit changes as the two asset prices vary,
# while the **red contour line** corresponds to the **zero-profit level** ($\Pi = 0$),
# that is, the **break-even** boundary separating the profit and loss regions.

# %%
# ==========================================
# 3D Συνάρτηση Κέρδους Π(x, y) = a·x + b·y - V
# Πεδίο: x,y ∈ [0, 2 * current_price]
# ==========================================

from mpl_toolkits.mplot3d import Axes3D

try:
    # Έλεγχος ότι υπάρχουν δύο μετοχές
    if len(valid_tickers) != 2:
        print("⚠️ Η συνάρτηση κέρδους απεικονίζεται μόνο όταν υπάρχουν δύο μετοχές.")
    else:
        # Επένδυση από προηγούμενο cell
        V = capital_input.value

        # Βάρη από χαρτοφυλάκιο min var με απόδοση ≥ m₀
        w1, w2 = min_var_m0_weights

        # Τελευταίες τιμές (τρέχουσες τιμές)
        last_prices = data.iloc[-1].values
        price1, price2 = last_prices

        # Υπολογισμός πλήθους μετοχών με βάση τα βάρη και το κεφάλαιο
        a = (V * w1) / price1
        b = (V * w2) / price2

        # --- Πεδίο τιμών (0 έως 2×)
        x_vals = np.linspace(0, 2 * price1, 100)
        y_vals = np.linspace(0, 2 * price2, 100)
        X, Y = np.meshgrid(x_vals, y_vals)

        # Συνάρτηση κέρδους
        Z = a * X + b * Y - V

        # ======= 3D ΕΠΙΦΑΝΕΙΑ =======
        fig = plt.figure(figsize=(10, 6))
        ax = fig.add_subplot(111, projection='3d')

        # Επιφάνεια κέρδους
        surf = ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none', alpha=0.85)

        # Επίπεδο Π = 0 (break-even)
        ax.contour(X, Y, Z, levels=[0], colors='red', linewidths=2, linestyles='--', offset=np.min(Z))

        # Άξονες & τίτλος
        ax.set_title(
            f"Συνάρτηση Κέρδους Π(x, y) = a·x + b·y - V\n"
            f"({valid_tickers[0]}: a={a:.2f}, {valid_tickers[1]}: b={b:.2f}, V={V:,.0f} €)"
        )
        ax.set_xlabel(f"Τιμή {valid_tickers[0]}")
        ax.set_ylabel(f"Τιμή {valid_tickers[1]}")
        ax.set_zlabel("Κέρδος Π(x, y) [€]")

        plt.show()

except NameError:
    print("❗ Δεν βρέθηκαν μεταβλητές από το προηγούμενο cell.\nΕκτέλεσε πρώτα το κουμπί 'Υπολογισμός'.")

# %% [markdown]
# # 🧮 Option Data Fetcher – Step 1: Stock and Option Selection
#
# This cell allows the user to interactively select multiple stock tickers, view their current market prices, and explore available option contracts using **Yahoo Finance** data.
#
# It performs the following steps:
#
# 1. **Ticker Selection** – The user enters one or more tickers (e.g., `AAPL, MSFT, GOOG`).
# 2. **Stock Prices** – The script automatically retrieves and displays the latest closing price for each stock.
# 3. **Common Expiration Dates** – Only the expiration dates available for **all** selected tickers are shown, ensuring consistency when comparing options.
# 4. **Option Chains** – For the chosen expiration date, the program displays a complete list of available **strike prices** along with their **Call** and **Put** premiums.
# 5. **User Input** – The user selects one Call and one Put strike for each ticker.
# 6. **Data Summary** – A summary table of all selected parameters (spot price, strikes, and option premiums) is displayed and stored in a Python dictionary named `options_data`.
#
# The resulting `options_data` dictionary will be used in the next cell to define payoff coefficients (`a_i`, `b_i`, `c_i`) and compute the profit or loss for each strategy.

# %%
# ============================================================
# Cell 1 (ipywidgets): Επιλογή tickers, κοινής λήξης, call & put
# - Dropdown για κοινές λήξεις
# - Dropdown ανά ticker για CALL/PUT strikes
# - Stable premiums (fallback σε mid όταν λείπει lastPrice)
# - Το options_data έχει την ίδια δομή όπως πριν
# ============================================================

# !pip install yfinance pandas numpy tabulate ipywidgets --quiet

import yfinance as yf
import pandas as pd
import numpy as np
from tabulate import tabulate
from IPython.display import display
import ipywidgets as widgets

pd.set_option("display.precision", 2)

# -----------------------------------------
# Βοηθητικές συναρτήσεις (σταθερότερες)
# -----------------------------------------
def _safe_last_close(tk):
    """Ασφαλής ανάκτηση τελευταίας τιμής κλεισίματος."""
    # 1) history
    try:
        h = tk.history(period="1d")
        if isinstance(h, pd.DataFrame) and not h.empty and "Close" in h:
            return float(h["Close"].iloc[-1])
    except Exception:
        pass
    # 2) fast_info
    try:
        fi = getattr(tk, "fast_info", None) or {}
        p = fi.get("lastPrice")
        if p is not None:
            return float(p)
    except Exception:
        pass
    # 3) info regularMarketPrice
    try:
        inf = getattr(tk, "info", None) or {}
        p = inf.get("regularMarketPrice")
        if p is not None:
            return float(p)
    except Exception:
        pass
    return float("nan")

def _mid(bid, ask):
    bid = pd.to_numeric(bid, errors="coerce")
    ask = pd.to_numeric(ask, errors="coerce")
    return (bid + ask) / 2.0

def _nearest_value(series, target):
    series = pd.to_numeric(series, errors="coerce").dropna()
    if series.empty:
        return np.nan
    idx = (series - float(target)).abs().idxmin()
    return float(series.loc[idx])

def _merged_chain(tk, exp):
    """Ενοποιεί calls/puts πάνω στο strike και συμπληρώνει premiums."""
    chain = tk.option_chain(exp)
    calls, puts = chain.calls.copy(), chain.puts.copy()
    for df in (calls, puts):
        for c in ["lastPrice", "bid", "ask", "strike"]:
            if c in df.columns:
                df[c] = pd.to_numeric(df[c], errors="coerce")

    calls = calls.rename(columns={"lastPrice": "Call_Premium"})
    puts  = puts.rename(columns={"lastPrice": "Put_Premium"})

    merged = pd.merge(
        calls[["strike", "Call_Premium", "bid", "ask"]].rename(columns={"bid":"bid_call","ask":"ask_call"}),
        puts[ ["strike", "Put_Premium", "bid", "ask"]].rename(columns={"bid":"bid_put","ask":"ask_put"}),
        on="strike", how="outer"
    ).sort_values("strike").reset_index(drop=True)

    # συμπλήρωση από mid όπου λείπουν lastPrice
    merged["Call_Premium"] = merged["Call_Premium"].fillna(_mid(merged["bid_call"], merged["ask_call"]))
    merged["Put_Premium"]  = merged["Put_Premium"].fillna(_mid(merged["bid_put"],  merged["ask_put"]))
    return merged

def _premium_from_df(merged, strike, side):
    """Επιστρέφει premium (float) για side='call' ή 'put' στο κοντινότερο strike."""
    if merged is None or merged.empty or not np.isfinite(strike):
        return float("nan")
    # Πλησιέστερη γραμμή
    i = (merged["strike"] - strike).abs().idxmin()
    if side == "call":
        val = merged.loc[i, "Call_Premium"]
        if pd.isna(val):
            # ύστατη προσπάθεια: mid από call bid/ask
            b = merged.loc[i, "bid_call"]
            a = merged.loc[i, "ask_call"]
            val = _mid(b, a)
        return float(val) if pd.notna(val) else float("nan")
    else:
        val = merged.loc[i, "Put_Premium"]
        if pd.isna(val):
            b = merged.loc[i, "bid_put"]
            a = merged.loc[i, "ask_put"]
            val = _mid(b, a)
        return float(val) if pd.notna(val) else float("nan")

# ------------------------------------------------------------
# Γενικά widgets & περιοχές εξόδου
# ------------------------------------------------------------
tickers_text = widgets.Text(
    description="Tickers:",
    placeholder="AAPL,MSFT,GOOG",
    layout=widgets.Layout(width="400px")
)
load_btn = widgets.Button(description="Φόρτωση", button_style="primary")
stock_out = widgets.Output()

exp_dd = widgets.Dropdown(description="Λήξη:", options=[], disabled=True, layout=widgets.Layout(width="300px"))
exp_out = widgets.Output()

per_ticker_box = widgets.VBox([])  # θα γεμίσει με ανά-ticker UI
summary_out = widgets.Output()

# Θα παραμένει διαθέσιμο για το 2ο κελί (όπως πριν)
options_data = {}

# Κρατάμε ανά ticker τα widgets/δεδομένα
_state = {}  # t -> {"tk":..., "S0":..., "merged":..., "call_dd":..., "put_dd":...}

# ------------------------------------------------------------
# Συνάρτηση περίληψης (tabulate) όπως πριν
# ------------------------------------------------------------
def _refresh_summary():
    with summary_out:
        summary_out.clear_output()
        rows = []
        for t, d in options_data.items():
            C = d["C_price"]; P = d["P_price"]
            rows.append([
                t, f"{d['S0']:.2f}",
                d["K_call"], f"{C:.2f}" if np.isfinite(C) else "NaN",
                d["K_put"],  f"{P:.2f}" if np.isfinite(P) else "NaN"
            ])
        if rows:
            print("\n✅ Επιλεγμένα δεδομένα:")
            print(tabulate(rows,
                           headers=["Ticker", "S0 ($)", "K_call", "Call Premium ($)", "K_put", "Put Premium ($)"],
                           tablefmt="fancy_grid"))
            print("\n📦 Τα δεδομένα αποθηκεύτηκαν στο options_data.")
            print("➡️ Τώρα μπορείς να τρέξεις το δεύτερο κελί για να υπολογίσεις το κέρδος.")
        else:
            print("— Δεν έχουν οριστεί επιλογές ακόμα —")

# ------------------------------------------------------------
# Handlers επιλογής strike
# ------------------------------------------------------------
def _on_strike_change(change, t, side):
    if change["name"] != "value":
        return
    sel_strike = change["new"]
    st = _state.get(t, {})
    merged = st.get("merged")
    S0 = st.get("S0", np.nan)

    if side == "call":
        Kc = float(sel_strike)
        Kp = float(options_data.get(t, {}).get("K_put", np.nan))
    else:
        Kp = float(sel_strike)
        Kc = float(options_data.get(t, {}).get("K_call", np.nan))

    C_price = _premium_from_df(merged, Kc, "call") if np.isfinite(Kc) else float("nan")
    P_price = _premium_from_df(merged, Kp, "put")  if np.isfinite(Kp) else float("nan")

    options_data[t] = {
        "S0": float(S0),
        "K_call": float(Kc),
        "K_put":  float(Kp),
        "C_price": float(C_price),
        "P_price": float(P_price),
    }
    _refresh_summary()

# ------------------------------------------------------------
# Handler επιλογής ημερομηνίας λήξης
# ------------------------------------------------------------
def _on_exp_change(change):
    if change["name"] != "value" or change["new"] in (None, ""):
        return
    exp = change["new"]
    per_ticker_box.children = []
    children = []

    for t, st in _state.items():
        tk = st["tk"]
        S0 = st["S0"]

        # Προσπάθεια λήψης option chain & ενοποίηση
        try:
            merged = _merged_chain(tk, exp)
        except Exception as e:
            merged = pd.DataFrame()
            warn = widgets.HTML(f"<b>❌ {t}:</b> αποτυχία ανάκτησης option chain ({e})")

            box = widgets.VBox([widgets.HTML(f"<h3>{t} — λήξη {exp}</h3>"), warn])
            children.append(box)
            continue

        st["merged"] = merged

        # strikes και προεπιλογή (ATM)
        strikes = pd.to_numeric(merged["strike"], errors="coerce").dropna().sort_values().unique().tolist()
        if not strikes:
            box = widgets.VBox([widgets.HTML(f"<h3>{t} — λήξη {exp}</h3>"),
                                widgets.HTML("❌ Δεν υπάρχουν διαθέσιμα strikes.")])
            children.append(box)
            continue

        # ATM επιλογές
        atm = _nearest_value(pd.Series(strikes), S0)

        # Dropdowns για CALL/PUT
        call_dd = widgets.Dropdown(
            description=f"{t} CALL:",
            options=[(f"{s:.2f}", float(s)) for s in strikes],
            value=float(atm),
            layout=widgets.Layout(width="300px")
        )
        put_dd = widgets.Dropdown(
            description=f"{t} PUT:",
            options=[(f"{s:.2f}", float(s)) for s in strikes],
            value=float(atm),
            layout=widgets.Layout(width="300px")
        )

        st["call_dd"] = call_dd
        st["put_dd"]  = put_dd

        # Αρχικοί premium υπολογισμοί + ενημέρωση options_data
        C_price = _premium_from_df(merged, call_dd.value, "call")
        P_price = _premium_from_df(merged, put_dd.value, "put")
        options_data[t] = {
            "S0": float(S0),
            "K_call": float(call_dd.value),
            "K_put":  float(put_dd.value),
            "C_price": float(C_price),
            "P_price": float(P_price),
        }

        # Πίνακας strikes (HTML για γρήγορη κύλιση)
        html_tbl = widgets.HTML(
            value=merged[["strike", "Call_Premium", "Put_Premium"]].round(2).to_html(index=False)
        )

        # Συνδέουμε τα events
        call_dd.observe(lambda ch, tt=t: _on_strike_change(ch, tt, "call"), names="value")
        put_dd.observe(lambda ch, tt=t: _on_strike_change(ch, tt, "put"), names="value")

        box = widgets.VBox([
            widgets.HTML(f"<h3>{t} — λήξη {exp} | Τρέχουσα τιμή: {S0:.2f} USD</h3>"),
            html_tbl,
            widgets.HBox([call_dd, put_dd]),
        ])
        children.append(box)

    per_ticker_box.children = children
    _refresh_summary()

# ------------------------------------------------------------
# Φόρτωση tickers -> εύρεση κοινών λήξεων και UI
# ------------------------------------------------------------
def _on_load_clicked(_btn):
    # καθαρισμοί UI
    stock_out.clear_output()
    exp_out.clear_output()
    per_ticker_box.children = []
    summary_out.clear_output()
    exp_dd.options = []
    exp_dd.disabled = True

    # parsing tickers
    raw = tickers_text.value.strip()
    tickers = [t.strip().upper() for t in raw.split(",") if t.strip()]
    if not tickers:
        with stock_out:
            print("❌ Δώσε τουλάχιστον ένα ticker, π.χ. AAPL,MSFT")
        return

    # Τρέχουσες τιμές
    valid = []
    with stock_out:
        rows = []
        for t in tickers:
            try:
                tk = yf.Ticker(t)
                S0 = _safe_last_close(tk)
                if not np.isfinite(S0):
                    print(f"⚠️  {t}: δεν βρέθηκε τιμή. Παραλείπεται.")
                    continue
                rows.append([t, f"{S0:.2f}"])
                valid.append((t, tk, S0))
            except Exception as e:
                print(f"⚠️  {t}: σφάλμα ({e}). Παραλείπεται.")
        if not valid:
            print("❌ Καμία έγκυρη μετοχή.")
            return
        print("📈 Τρέχουσες τιμές μετοχών:")
        print(tabulate(rows, headers=["Ticker", "Τιμή ($)"], tablefmt="fancy_grid"))

    # Εύρεση κοινών λήξεων
    all_sets = []
    for t, tk, _S0 in valid:
        try:
            exps = list(getattr(tk, "options", []) or [])
        except Exception:
            exps = []
        all_sets.append(set(exps))
        _state[t] = {"tk": tk, "S0": _S0, "merged": None, "call_dd": None, "put_dd": None}

    non_empty = [s for s in all_sets if s]
    if not non_empty:
        with exp_out:
            print("❌ Δεν υπάρχουν διαθέσιμες λήξεις για τα επιλεγμένα tickers.")
        return

    common = sorted(list(set.intersection(*non_empty)))
    if not common:
        with exp_out:
            print("❌ Δεν υπάρχουν κοινές ημερομηνίες λήξης για όλα τα tickers.")
        return

    with exp_out:
        print("✅ Κοινές ημερομηνίες λήξης:")
        for e in common:
            print("   •", e)

    # Γέμισμα dropdown & ενεργοποίηση
    exp_dd.options = common
    exp_dd.value = common[0]  # προεπιλογή
    exp_dd.disabled = False

# ------------------------------------------------------------
# Σύνδεση handlers και απόδοση UI
# ------------------------------------------------------------
load_btn.on_click(_on_load_clicked)
exp_dd.observe(_on_exp_change, names="value")

ui = widgets.VBox([
    widgets.HTML("<h2>Options UI με ipywidgets</h2>"),
    widgets.HBox([tickers_text, load_btn]),
    stock_out,
    widgets.HBox([exp_dd]),
    exp_out,
    per_ticker_box,
    widgets.HTML("<hr>"),
    summary_out
])

display(ui)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 💼 Option Portfolio Payoff Analyzer – Step 2: Profit Computation
#
# This cell computes the **net profit (Πₙₑₜ)** of a multi-asset option strategy using the market data and option parameters selected in the previous step.
#
# **Overview:**
#
# 1. **Coefficient Input:**
#    For each stock \( S_i \), the user enters three coefficients:
#    - \( a_i \): number of shares held (long or short),
#    - \( b_i \): number of Call options,
#    - \( c_i \): number of Put options.
#    These define the position weights in the overall portfolio.
#
# 2. **Initial Investment:**
#    The script calculates the total cost of the portfolio based on the current stock prices and option premiums.
#
# 3. **Symbolic Profit Function:**
#    The cell constructs and displays the analytical expression of the net profit function
#    \[
#    \Pi_{\text{net}}(x_1, \ldots, x_n)
#    \]
#    using **MathJax**, showing how the profit depends on the future stock prices.
#
# 4. **Profit Evaluation:**
#    It defines the function \( \Pi_{\text{net}}(x) \) numerically, including:
#    - linear gains/losses from shares,
#    - payoff from Calls and Puts,
#    - and initial costs for all positions.
#
# 5. **Optimization (Profit Minimum):**
#    The script searches for the **minimum possible profit** under $ S_i \ge 0 $:
#    - Uses `scipy.optimize.minimize` (L-BFGS-B) for continuous optimization,
#    - Then performs a dense **grid search** to verify the global minimum.
#
# 6. **Results & Visualization:**
#    - Prints the total investment and the minimum profit value.
#    - For one or two assets, it visualizes the profit function:
#      - **1 asset:** line plot of Πₙₑₜ vs stock price.
#      - **2 assets:** contour plot of the two-dimensional profit surface.
#
# This step enables users to explore the payoff structure and risk exposure of complex option portfolios, combining analytical formulas, numerical optimization, and visual analysis.

# %%
# ============================================================
# Cell 2: Επιλογή a_i, b_i, c_i και υπολογισμός κέρδους
# για S_i ≥ 0
# ============================================================

import numpy as np
import matplotlib.pyplot as plt
from itertools import product
from IPython.display import display, Math

# ------------------------------------------------------------
# 0. Λήψη tickers από το πρώτο κελί
# ------------------------------------------------------------
try:
    tickers = list(options_data.keys())
    if not tickers:
        raise ValueError("Το options_data είναι άδειο.")
except Exception as e:
    raise RuntimeError(
        f"❌ Δεν εντοπίστηκαν tickers από το πρώτο κελί ({e}). "
        "Βεβαιώσου ότι έχεις τρέξει πρώτα το Cell 1."
    )






# ------------------------------------------------------------
# 1. Είσοδος συντελεστών a_i, b_i, c_i
# ------------------------------------------------------------
a, b, c = [], [], []
for t in tickers:
    print(f"\nΕισαγωγή συμβολαίων για {t}:")
    a_i = float(input("a_i (μετοχές): "))
    b_i = float(input("b_i (calls): "))
    c_i = float(input("c_i (puts): "))
    a.append(a_i)
    b.append(b_i)
    c.append(c_i)

a, b, c = np.array(a), np.array(b), np.array(c)

# ------------------------------------------------------------
# 2. Υπολογισμός συνολικού κόστους επένδυσης
# ------------------------------------------------------------
total_investment = 0.0
for i, t in enumerate(tickers):
    S0 = options_data[t]["S0"]
    C = options_data[t]["C_price"]
    P = options_data[t]["P_price"]
    total_investment += a[i]*S0 + b[i]*C + c[i]*P

print("\n💰 Συνολικό αρχικό ποσό επένδυσης:")
print(f"{total_investment:.2f} $")

# ------------------------------------------------------------
# 3. MathJax εμφάνιση της συνάρτησης Π_net με αριθμητικούς συντελεστές
# ------------------------------------------------------------
profit_latex = r"\Pi_{\text{net}}(x_1,\ldots,x_n) = "

terms = []
for i, t in enumerate(tickers):
    S0 = options_data[t]["S0"]
    Kc = options_data[t]["K_call"]
    Kp = options_data[t]["K_put"]
    C = options_data[t]["C_price"]
    P = options_data[t]["P_price"]

    term = (
        fr"{a[i]:.2f}(x_{{{i+1}}} - {S0:.2f})"
        + fr" + {b[i]:.2f}\max(x_{{{i+1}}} - {Kc:.2f}, 0)"
        + fr" + {c[i]:.2f}\max({Kp:.2f} - x_{{{i+1}}}, 0)"
        + fr" - {b[i]:.2f}\,{C:.2f}"
        + fr" - {c[i]:.2f}\,{P:.2f}"
    )
    terms.append(term)

profit_latex += " + ".join(terms)
display(Math(profit_latex))

# ------------------------------------------------------------
# 4. Συνάρτηση καθαρού κέρδους
# ------------------------------------------------------------
def profit_net(x):
    x = np.array(x)
    total = 0.0
    for i, t in enumerate(tickers):
        S0 = options_data[t]["S0"]
        Kc = options_data[t]["K_call"]
        Kp = options_data[t]["K_put"]
        C = options_data[t]["C_price"]
        P = options_data[t]["P_price"]
        total += (
            a[i]*(x[i]-S0)
            + b[i]*np.maximum(x[i]-Kc, 0)
            + c[i]*np.maximum(Kp-x[i], 0)
            - b[i]*C
            - c[i]*P
        )
    return total

# ------------------------------------------------------------
# 5. Υπολογισμός ελάχιστου (ανάλυση κομματιακής γραμμικότητας)
# ------------------------------------------------------------
bounds = [(0, 5*options_data[t]["S0"]) for t in tickers]

# Κρίσιμα σημεία για κάθε μετοχή: 0, Kp, Kc, 5S0
critical_points = []
for t in tickers:
    S0 = options_data[t]["S0"]
    Kc = options_data[t]["K_call"]
    Kp = options_data[t]["K_put"]
    pts = sorted(set([0, Kp, Kc, 5*S0]))
    critical_points.append(pts)

# Όλοι οι συνδυασμοί των κρίσιμων σημείων
candidate_points = list(product(*critical_points))

# Υπολογισμός Π_net για κάθε συνδυασμό
min_val = float('inf')
x_min = None
for combo in candidate_points:
    val = profit_net(combo)
    if val < min_val:
        min_val = val
        x_min = combo

# ------------------------------------------------------------
# 6. Εμφάνιση αποτελεσμάτων με MathJax
# ------------------------------------------------------------
result_latex = (
    r"\text{Ελάχιστο καθαρού κέρδους: } \Pi_{\min} = "
    + f"{min_val:.2f}"
    + r", \quad ("
    + ", ".join([fr"x_{{{i+1}}}^* = {x_min[i]:.2f}" for i in range(len(tickers))])
    + r")"
)
display(Math(result_latex))

print("\n=============================================")
print(f"💰 Συνολικό ποσό επένδυσης: {total_investment:.2f} $")
print("\n🔹 Ελάχιστο καθαρού κέρδους Π_net:")
for i, t in enumerate(tickers):
    print(f"{t}: S* = {x_min[i]:.2f}")
print(f"Π_min = {min_val:.2f}")
print("=============================================")

# ------------------------------------------------------------
# 7. Οπτικοποίηση (για 1 ή 2 tickers)
# ------------------------------------------------------------
from mpl_toolkits.mplot3d import Axes3D  # 3D plotting support

if len(tickers) == 1:
    xs = np.linspace(0, 5*options_data[tickers[0]]["S0"], 400)
    ys = [profit_net([x]) for x in xs]
    plt.plot(xs, ys)
    plt.axhline(0, color='black', lw=0.8)
    plt.xlabel("Τιμή μετοχής")
    plt.ylabel("Καθαρό κέρδος Π_net(x)")
    plt.title(f"Π_net(x) για {tickers[0]}")
    plt.grid(True)
    plt.show()

elif len(tickers) == 2:
    X = np.linspace(0, 5*options_data[tickers[0]]["S0"], 80)
    Y = np.linspace(0, 5*options_data[tickers[1]]["S0"], 80)
    Xg, Yg = np.meshgrid(X, Y)
    Z = np.zeros_like(Xg)

    for i in range(Xg.shape[0]):
        for j in range(Xg.shape[1]):
            Z[i, j] = profit_net([Xg[i, j], Yg[i, j]])

    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')
    surf = ax.plot_surface(Xg, Yg, Z, cmap='viridis', edgecolor='none', alpha=0.9)
    ax.set_xlabel(tickers[0])
    ax.set_ylabel(tickers[1])
    ax.set_zlabel("Π_net(x₁, x₂)")
    ax.set_title("3D επιφάνεια καθαρού κέρδους Π_net(x₁, x₂)")
    fig.colorbar(surf, shrink=0.6, aspect=10)
    plt.show()
# Out:
# Εισαγωγή συμβολαίων για AAPL:
# a_i (μετοχές): 1
# b_i (calls): 0
# c_i (puts): 10
#
# Εισαγωγή συμβολαίων για MSFT:
# a_i (μετοχές): 1
# b_i (calls): 0
# c_i (puts): 10
#
# 💰 Συνολικό αρχικό ποσό επένδυσης:
# 1549.07 $
# $\displaystyle \Pi_{\text{net}}(x_1,\ldots,x_n) = 1.00(x_{1} - 270.04) + 0.00\max(x_{1} - 270.00, 0) + 10.00\max(270.00 - x_{1}, 0) - 0.00\,37.90 - 10.00\,27.10 + 1.00(x_{2} - 514.33) + 0.00\max(x_{2} - 515.00, 0) + 10.00\max(515.00 - x_{2}, 0) - 0.00\,69.00 - 10.00\,49.37$
# $\displaystyle \text{Ελάχιστο καθαρού κέρδους: } \Pi_{\min} = -764.07, \quad (x_{1}^* = 270.00, x_{2}^* = 515.00)$
# ...
# 💰 Συνολικό ποσό επένδυσης: 1549.07 $
#
# 🔹 Ελάχιστο καθαρού κέρδους Π_net:
# AAPL: S* = 270.00
# MSFT: S* = 515.00
# Π_min = -764.07
# ...

# %% [markdown]
# ### 📊 Cell 3: Scenario-based Profit Evaluation (Interactive)
#
# This cell allows the user to **input multiple market scenarios** (possible future stock prices)
# and compute the **net portfolio profit (Π_net)** for each one.
#
# - For each underlying asset (ticker), you can manually set the final stock price `S_i` in every scenario.
# - You can choose how many scenarios to include using the *“Number of scenarios”* selector.
# - Each scenario corresponds to one possible market outcome at option maturity.
# - When you click **“💰 Compute Π_net for all scenarios”**, a table is displayed showing:
#   - The stock prices for each scenario (`S_1`, `S_2`, …)
#   - The computed **net profit (Π_net)** in dollars.
#
# This tool is useful for analyzing **how the portfolio performs** under different market conditions
# and identifying which combinations of final stock prices yield profit or loss.
#
# > 💡 Tip: You can extend this by adding derived metrics (e.g., percentage return, delta, or breakeven points)
# > to explore portfolio sensitivity and hedging effectiveness.

# %%
# ============================================================
# Cell 3: Scenario-based Profit Evaluation (with LaTeX export)
# ============================================================

import ipywidgets as widgets
import pandas as pd
from IPython.display import display, clear_output, Markdown

# Select number of scenarios
num_scenarios_box = widgets.BoundedIntText(
    value=2,
    min=1,
    max=5,
    step=1,
    description='Number of scenarios:',
    style={'description_width': 'initial'}
)

# Area for scenario inputs
scenarios_box = widgets.VBox()

# Output areas
output_area = widgets.Output()
latex_output = widgets.Output()

def create_scenario_boxes(n):
    """Create input fields for n scenarios"""
    rows = []
    for s in range(n):
        boxes = []
        for t in tickers:
            box = widgets.FloatText(
                value=options_data[t]["S0"],
                description=f"{t} (S{ s+1 }):",
                style={'description_width': 'initial'},
                layout=widgets.Layout(width='180px')
            )
            boxes.append(box)
        row = widgets.HBox(boxes)
        rows.append(row)
    return rows

def update_scenarios(change):
    """Refresh input boxes when scenario count changes"""
    n = change['new']
    scenarios_box.children = create_scenario_boxes(n)

num_scenarios_box.observe(update_scenarios, names='value')
scenarios_box.children = create_scenario_boxes(num_scenarios_box.value)

# Button for computing profits
calc_button = widgets.Button(
    description="💰 Compute Π_net for all scenarios",
    button_style='success',
    icon='calculator'
)

def on_calculate(b):
    with output_area:
        clear_output()
        all_results = []

        for s, row in enumerate(scenarios_box.children):
            current_prices = [box.value for box in row.children]
            profit = profit_net(current_prices)
            all_results.append(current_prices + [profit])

        columns = [f"S_{i+1} ({t})" for i, t in enumerate(tickers)] + ["Π_net ($)"]
        df = pd.DataFrame(all_results, columns=columns)

        display(df.style.set_caption("📊 Net profit for each market scenario"))

        # --- Export to LaTeX ---
        latex_str = df.to_latex(
            index=False,
            float_format="%.2f",
            caption="Portfolio net profit (Π_net) for multiple market scenarios",
            label="tab:profit_scenarios"
        )

        with latex_output:
            clear_output()
            display(Markdown("### 🧾 LaTeX Export"))
            display(Markdown(f"```latex\n{latex_str}\n```"))

calc_button.on_click(on_calculate)

# Display the widgets
display(
    widgets.VBox([
        num_scenarios_box,
        scenarios_box,
        calc_button,
        output_area,
        latex_output
    ])
)

# %% [markdown]
# # 📈 CAPM (Capital Asset Pricing Model) Analysis
#
# This cell applies the **Capital Asset Pricing Model (CAPM)** to estimate each stock’s sensitivity to market movements (Beta), its excess performance over the market (Alpha), and the explanatory power of the model (R²).
#
# **Procedure:**
#
# 1. **Data Retrieval**
#    - Downloads daily closing prices for the selected stocks and the S&P 500 index (`^GSPC`).
#    - Uses the same historical window (`months_back`) as before.
#
# 2. **Return Calculation**
#    - Computes daily returns for assets and market.
#    - Adjusts to *excess returns* by subtracting the daily risk-free rate.
#
# 3. **CAPM Regression**
#    The model fitted for each stock is:
#
#    $$
#    (r_i - r_f) = \alpha_i + \beta_i (r_m - r_f) + \varepsilon_i
#    $$
#
#    where
#    - $\alpha_i$ is the abnormal return (intercept),
#    - $\beta_i$ measures the market risk exposure,
#    - and $r_m - r_f$ is the excess market return.
#
# 4. **Results**
#    The table shows **Alpha**, **Beta**, and **R²** for each stock:
#    - **Beta > 1** → stock more volatile than the market
#    - **Beta < 1** → less sensitive to market moves
#    - **Alpha > 0** → outperformance vs. CAPM prediction

# %%
# ============================================================
# Cell 3: CAPM (Capital Asset Pricing Model) + LaTeX Export
# ============================================================

import pandas as pd
import numpy as np
import yfinance as yf
import statsmodels.api as sm
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from tabulate import tabulate
from IPython.display import display, Markdown

# ------------------------------------------------------------
# 0. Retrieve tickers from Cell 1
# ------------------------------------------------------------
try:
    tickers = list(options_data.keys())
    if not tickers:
        raise ValueError("The dictionary options_data is empty.")
except Exception as e:
    raise RuntimeError(
        f"❌ Could not retrieve tickers from Cell 1 ({e}). "
        "Please run Cell 1 first."
    )

# Look-back period in months
months_back = 50

# ------------------------------------------------------------
# 1. Download price data
# ------------------------------------------------------------
end_date = datetime.today() - timedelta(days=1)
start_date = end_date - timedelta(days=months_back * 30)

print(f"📅 Period: {start_date.date()} → {end_date.date()}")

data = yf.download(tickers, start=start_date, end=end_date)['Close']
returns = data.pct_change().dropna()

# ------------------------------------------------------------
# 2. Market data (S&P 500)
# ------------------------------------------------------------
market_ticker = "^GSPC"
market_data = yf.download(market_ticker, start=start_date, end=end_date)['Close']
market_returns = market_data.pct_change().dropna()

aligned_returns = returns.loc[returns.index.intersection(market_returns.index)]
market_returns = market_returns.loc[aligned_returns.index]

# ------------------------------------------------------------
# 3. CAPM Parameters
# ------------------------------------------------------------
risk_free_rate = 0.02  # annual risk-free rate
rf_daily = (1 + risk_free_rate)**(1/252) - 1
excess_market_return = market_returns - rf_daily

# ------------------------------------------------------------
# 4. Fit CAPM regressions
# ------------------------------------------------------------
capm_results = {}

for ticker in aligned_returns.columns:
    excess_stock_return = aligned_returns[ticker] - rf_daily
    X = sm.add_constant(excess_market_return)
    model = sm.OLS(excess_stock_return, X).fit()
    alpha, beta = model.params
    capm_results[ticker] = {
        "Alpha": alpha,
        "Beta": beta,
        "R²": model.rsquared
    }

# ------------------------------------------------------------
# 5. Display results in table
# ------------------------------------------------------------
capm_df = pd.DataFrame(capm_results).T
capm_df.columns = ["Alpha", "Beta", "R²"]

print("\n📈 CAPM Results:\n")
print(tabulate(
    capm_df.reset_index().rename(columns={"index": "Ticker"}).values,
    headers=["Ticker", "Alpha", "Beta", "R²"],
    tablefmt="fancy_grid",
    floatfmt=(".6f", ".4f", ".3f")
))

display(capm_df.style.format({"Alpha": "{:.6f}", "Beta": "{:.4f}", "R²": "{:.3f}"})
                .set_caption("CAPM Model Results"))

# ------------------------------------------------------------
# 6. Generate LaTeX table (in English)
# ------------------------------------------------------------
latex_table = capm_df.reset_index().rename(columns={"index": "Ticker"})
latex_str = latex_table.to_latex(
    index=False,
    float_format="%.4f",
    caption="Results of the Capital Asset Pricing Model (CAPM)",
    label="tab:capm_results",
    column_format="lccc",
    header=["Ticker", r"$\\alpha_i$", r"$\\beta_i$", r"$R^2$"],
    escape=False
)

display(Markdown("### 📄 LaTeX Export"))
display(Markdown(f"```\n{latex_str}\n```"))

# ------------------------------------------------------------
# 7. Visualization: CAPM regression plots
# ------------------------------------------------------------
for ticker in aligned_returns.columns:
    excess_stock_return = aligned_returns[ticker] - rf_daily
    X = sm.add_constant(excess_market_return)
    model = sm.OLS(excess_stock_return, X).fit()
    alpha, beta = model.params

    plt.figure(figsize=(7, 5))
    plt.scatter(excess_market_return, excess_stock_return, alpha=0.5, label="Daily excess returns")
    plt.plot(
        excess_market_return,
        alpha + beta * excess_market_return,
        color="red", lw=2,
        label=f"CAPM line: y = {alpha:.4f} + {beta:.2f}x"
    )
    plt.title(f"CAPM Regression for {ticker}")
    plt.xlabel("Excess Market Return $(R_m - R_f)$")
    plt.ylabel(f"Excess Return of {ticker} $(R_i - R_f)$")
    plt.legend()
    plt.grid(True)
    plt.show()

print("\n✅ CAPM analysis and LaTeX export completed.")
# Out:
# /tmp/ipython-input-147500849.py:38: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)['Close']
# [*********************100%***********************]  2 of 2 completed
# 📅 Period: 2021-09-25 → 2025-11-03
# /tmp/ipython-input-147500849.py:45: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   market_data = yf.download(market_ticker, start=start_date, end=end_date)['Close']
# [*********************100%***********************]  1 of 1 completed
# 📈 CAPM Results:
#
# ╒══════════╤═════════╤════════╤══════════╕
# │ Ticker   │   Alpha │   Beta │       R² │
# ╞══════════╪═════════╪════════╪══════════╡
# │ HTZ      │ -0.0008 │  1.359 │ 0.096029 │
# ├──────────┼─────────┼────────┼──────────┤
# │ TSLA     │  0.0004 │  2.049 │ 0.339409 │
# ╘══════════╧═════════╧════════╧══════════╛
# <style type="text/css">
# </style>
# <table id="T_e08ec" class="dataframe">
# ...
